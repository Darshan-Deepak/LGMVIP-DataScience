# %% [markdown]
# ## TASK-2 IMAGE TO PENCIL SKETCH WITH PYTHON

# %% [markdown]
# ### Name: DARSHAN DEEPAK ARUGOLLU

# %% [markdown]
# ### IMPORT LIBRARY

# %%
import cv2

# %% [markdown]
# ### READ IMAGE

# %%
image = cv2.imread("E:\DARSHAN\LETSGROWMORE INTERNSHIP\puppy.jpg")
#image

# %% [markdown]
# ### TO SHOW OR DISPLAY IMAGE

# %%
cv2.imshow("dog", image)
cv2.waitKey(0)
# Out:
# -1

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow("New Dog", gray_image)
cv2.waitKey(0)
# Out:
# -1

# %%
inverted_image = 255 - gray_image
cv2.imshow("Inverted", inverted_image)
cv2.waitKey()
# Out:
# -1

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2.imshow("Sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.imshow("original image", image)
cv2.imshow("pencil sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ### Read the image in RGB format

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# ### Create a new image by converting the original image to grayscale

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[ 76,  77,  77, ..., 205, 205, 204],
#        [ 76,  77,  77, ..., 206, 205, 204],
#        [ 77,  77,  77, ..., 206, 205, 205],
#        ...,
#        [176, 176, 176, ..., 137, 143, 138],
#        [168, 167, 167, ..., 138, 143, 140],
#        [159, 157, 158, ..., 139, 144, 140]], dtype=uint8)

# %%
plt.imshow(gray_image)

# %%
 plt.imshow(gray_image)

# %% [markdown]
# ### Inverting Image

# %%
inverted_image = 255-gray_image
#inverted_image = cv2.bitwise_not(gray_image)
plt.imshow(inverted_image)

# %% [markdown]
# ### Blur the image by using the Gaussian Function

# %%
blurred = cv2.GaussianBlur(inverted_image,(21,21),0)
plt.imshow(blurred)

# %% [markdown]
# ### Invert the blurred image for final image(pencil sketch)

# %%
inverted_blurred = 255-blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
plt.imshow(pencil_sketch)

# %% [markdown]
# ### Final Sketch

# %%
cv2.imshow("puppy sketch",pencil_sketch)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ### Original image and the pencil sketch

# %%
cv2.imshow("original image", image)
cv2.imshow("pencil sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# -1
